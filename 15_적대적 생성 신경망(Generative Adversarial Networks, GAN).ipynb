# %% [markdown]
# - 내용 및 코드 참조
#
#   - 케라스 창시자로부터 배우는 딥러닝
#
#   - 미술관에 GAN 딥러닝 실전 프로젝트

# %% [markdown]
# # 적대적 생성 신경망(Generative Adversarial Networks, GAN)
#
# - 2014년, Ian Goodfellow 소개
#
# - VAE와는 다른 방법으로 이미지 잠재 공간을 학습
#
# - 직관적으로 이해하는 방법
#
#   - 가짜 피카소 그림을 그리는 위조범과 이를 판별하는 판매상의 관계
#
#   - 위조품과 진짜 그림을 섞어서 판매상에게 보여주며
#     그림이 진짜인지 가짜인지 판매상은 판별하고 이를 위조범에게 피드백
#
#   - 처음에는 형편없는 그림을 그리다가 점점 피카소의 스타일을 모방하게 되고
#     판매상은 위조품을 구분하는데 점점 더 전문가가 되어감
#
# - GAN의 네트워크
#
#   - 생성자 네트워크(generator network)
#
#     - 랜덤 벡터(잠재 공간의 무작위한 포인트)를 입력으로 받아 이를 합성된 이미지로 디코딩
#
#   - 판별자 네트워크(discriminator netowrk)
#
#     - 이미지(실제 또는 가짜 이미지)를 입력으로 받아 훈련 세트에서 온 이미지인지 생성자가 만든 이미지인지 판별
#
# - GAN은 최적화의 최솟값이 고정되어 있지 않음
#
#   - 보통의 경사하강법은 **고정된 손실공간**에서 언덕을 내려오는 훈련 방법이지만
#     GAN은 매 단계가 조금씩 전체 공간을 바꾸기 때문에 최적화 과정이 최솟값을 찾는 것이 어려움
#
#   - 두 힘간의 평형점을 찾는 시스템
#
#   - 따라서, 학습과정이 매우 어려움
#     즉, 적절한 파라미터를 찾고 조정해야함
#
#   <img src="https://paperswithcode.com/media/methods/gan.jpeg">
#
#   <sub>[이미지 출처] https://paperswithcode.com/method/gan</sub>

# %% [markdown]
# ## GAN의 구현 (DCGAN)
#
# - CIFAR10 데이터셋 사용
#
# - generator 네트워크는 (latent_dim,) 크기의 벡터를 (32, 32, 3) 크기의 이미지로 매핑
#
# - discriminator 네트워크는 (32, 32, 3) 크기의 이미지가 진짜일 확률을 추정하여 이진값으로 매핑
#
# - 생성자와 판별자를 연결하는 gan 네트워크를 만듬
#
#   - gan(x) = discriminator(generator(x))
#
# - 진짜/가짜 레이블과 함께 진짜 이미지와 가짜 이미지 샘플을 사용하여 판별자를 훈련 (일반적인 이미지 분류 모델 훈련과 동일)
#
# - 생성자를 훈련하려면 gan 모델의 손실에 대한 생성자 가중치의 그래디언트를 사용
#
#   - 매 단계마다 생성자에 의해 디코딩된 이미지를 판별자가 "진짜"로 분류하도록 만다는 방향으로 생성자의 가중치를 이동
#
#   - 판별자를 속이도록 생성자를 훈련한다는 말

# %% [markdown]
# ## 학습 방법
#
# - 마지막 활성화 함수로 sigmoid 대신 tanh함수 사용
#
# - 균등분포가 아니고 정규 분포(가우시안 분포)를 사용하여 잠재 공간에서 포인트를 샘플링
#
# - 무작위성을 주입
#
#   - 판별자에 드롭아웃을 사용
#
#   - 판별자를 위해 레이블에 랜덤 노이즈를 추가
#
# - 희소한 그래디언트는 GAN 훈련에 방해가 될 수 있음
#
#   - 최대 풀링 대신 스트라이드 합성곱을 사용하여 다운샘플링
#
#   - ReLU 대신 LeakyReLU 사용
#
# - 생성자에서 픽셀 공간을 균일하게 다루지 못하여 생성된 이미지에서 체스판 모양이 종종 나타남.
#   이를 위해 생성자와 판별자에서 스트라이드 Conv2DTranpose나 Conv2D를 사용할 때 스트라이드 크기로 나누어 질 수 있는 커널 크기 사용
#
#   - 커널 크기가 스트라이드의 배수가 아니면 픽셀이 공평하게 합성곱 되지 않음
#     커널 크기를 스트라이드로 나누었을 때 나머지 크기에 해당하는 픽셀이 더 많이 업샘플링에 참여하게 됨

# %% [markdown]
# ### GAN 생성자 네트워크

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, LeakyReLU, Reshape, Conv2D, Conv2DTranspose, Flatten, Dropout
from tensorflow.keras.models import Model
import numpy as np

# %%
latent_dim = 32
height = 32
width = 32
channels = 3

# %%
generator_input = Input(shape=(latent_dim, ))

# %%
x = Dense(128 * 16 * 16)(generator_input)
x = LeakyReLU()(x)
x = Reshape((16, 16, 128))(x)

x = Conv2D(256, 5, padding='same')(x)
x = LeakyReLU()(x)

x = Conv2DTranspose(256, 4, strides=2, padding='same')(x)
x = LeakyReLU()(x)

x = Conv2D(256, 5, padding='same')(x)
x = LeakyReLU()(x)
x = Conv2D(256, 5, padding='same')(x)
x = LeakyReLU()(x)

x = Conv2D(channels, 7, activation='tanh', padding='same')(x)

# %%
generator = Model(generator_input, x)
generator.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32)]              0
# _________________________________________________________________
# dense (Dense)                (None, 32768)             1081344
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 32768)             0
# _________________________________________________________________
# reshape (Reshape)            (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 16, 16, 256)       819456
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 32, 32, 256)       1048832
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 256)       1638656
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 256)       1638656
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 3)         37635
# =================================================================
# Total params: 6,264,579
# Trainable params: 6,264,579
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### GAN 판별자 네트워크

# %%
discriminator_input = Input(shape=(height, width, channels))

# %%
x = Conv2D(128, 3)(discriminator_input)
x = LeakyReLU()(x)
x = Conv2D(128, 4, strides=2)(x)
x = LeakyReLU()(x)
x = Conv2D(128, 4, strides=2)(x)
x = LeakyReLU()(x)
x = Conv2D(128, 4, strides=2)(x)
x = LeakyReLU()(x)
x = Flatten()(x)
x = Dropout(0.4)(x)
x = Dense(1, activation='sigmoid')(x)

# %%
discriminator = Model(discriminator_input, x)
discriminator.summary()
# Out:
# Model: "functional_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 30, 30, 128)       3584
# _________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)   (None, 30, 30, 128)       0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 14, 14, 128)       262272
# _________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)   (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 6, 6, 128)         262272
# _________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)   (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 2, 2, 128)         262272
# _________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)   (None, 2, 2, 128)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 790,913
# Trainable params: 790,913
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import RMSprop

# %%
discriminator_optimizer = RMSprop(lr=0.0008, clipvalue=1.0, decay=1e-8)
discriminator.compile(optimizer=discriminator_optimizer, loss='binary_crossentropy')

# %% [markdown]
# ### 적대적 네트워크
# - 생성자와 판별자를 연결
#
# - 훈련할 때 생성자가 판별자를 속이는 능력이 커지도록 학습
#
# - 잠재 공간의 포인트를 진짜 또는 가짜의 분류 결정으로 변환
#
# - 훈련에 사용되는 target label은 항상 "진짜 이미지"
#
# - 훈련하는 동안 판별자를 동결(학습되지 않도록)하는 것이 매우 중요!
#
#   - 판별자의 가중치가 훈련하는 동안 업데이트되면 판별자는 항상 진짜를 예측하도록 훈련됨

# %%
discriminator.trainable=False

gan_input = Input(shape=(latent_dim, ))
gan_output = discriminator(generator(gan_input))
gan = Model(gan_input, gan_output)

gan_optimizer = RMSprop(lr=0.0004, clipvalue=1.0, decay=1e-8)
gan.compile(optimizer=gan_optimizer, loss='binary_crossentropy')

# %% [markdown]
# ### GAN 훈련 구현
#
# - DCGAN 구현
#
# - 매 반복마다 아래의 과정 수행
#
#   1. 잠재 공간에서 무작위로 포인트를 뽑음(랜덤 노이즈)
#
#   2. 랜덤 노이즈를 사용하여 generator에서 이미지를 생성
#
#   3. 생성된 이미지와 진짜 이미지를 섞음
#
#   4. 진짜와 가짜가 섞인 이미지와 이에 대응하는 타깃을 사용하여 discriminator를 훈련
#     타킷은 진짜 또는 가짜
#
#   5. 잠재 공간에서 무작위로 새로운 포인트를 뽑음
#
#   6. 랜덤 벡터를 사용하여 gan을 훈련.
#     모든 타깃은 진짜로 설정.
#     - 판별자가 생성된 이미지를 모두 "진짜 이미지"라고 예측하도록 생성자의 가중치를 업데이트.
#       (판별자는 동결되기 때문에 생성자만 업데이트)

# %%
import os
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing import image

# %% [markdown]
# #### CIFAR10 데이터 로드

# %%
(x_train, y_train), (_, _) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step

# %% [markdown]
# #### 개구리 이미지를 선택

# %%
x_train = x_train[y_train.flatten() == 6]

# %% [markdown]
# #### 데이터 정규화

# %%
x_train = x_train.reshape((x_train.shape[0], ) + (height, width, channels)).astype('float32') / 255.

# %%
iterations = 10000
batch_size = 20

save_dir = '/content/gan_images/'
if not os.path.exists(save_dir):
  os.mkdir(save_dir)

# %% [markdown]
# #### 학습

# %%
start = 0
for step in range(iterations):
  random_latent_vectors = np.random.normal(size=(batch_size, latent_dim))
  generated_images = generator.predict(random_latent_vectors)

  stop = start + batch_size
  real_images = x_train[start:stop]
  combined_images = np.concatenate([generated_images, real_images])

  labels = np.concatenate([np.ones((batch_size, 1)),
                           np.zeros((batch_size, 1))])
  labels += 0.05 * np.random.random(labels.shape)

  d_loss = discriminator.train_on_batch(combined_images, labels)

  random_latent_vectors = np.random.normal(size=(batch_size, latent_dim))
  misleading_targets = np.zeros((batch_size, 1))

  a_loss = gan.train_on_batch(random_latent_vectors, misleading_targets)

  start += batch_size
  if start > len(x_train) - batch_size:
    start = 0

  if step % 100 == 0:
    gan.save_weights('gan.h5')

    print('\nstep: {}'.format(step))
    print(' discriminator loss: {}'.format(d_loss))
    print(' adversarial loss: {}'.format(a_loss))

    img = image.array_to_img(generated_images[0] * 255., scale=False)
    img.save(os.path.join(save_dir, 'generated_frog' + str(step) + '.png'))

    img = image.array_to_img(generated_images[0] * 255., scale=False)
    img.save(os.path.join(save_dir, 'real_frog' + str(step) + '.png'))
# Out:
# step: 0
#  discriminator loss: 0.6828057169914246
#  adversarial loss: 0.38788360357284546
#
# step: 100
#  discriminator loss: 0.7049353718757629
#  adversarial loss: 0.8160989880561829
#
# step: 200
#  discriminator loss: 0.6837619543075562
#  adversarial loss: 1.379532814025879
#
# step: 300
#  discriminator loss: 0.6986121535301208
#  adversarial loss: 0.740463376045227
#
# step: 400
#  discriminator loss: 0.6994577646255493
#  adversarial loss: 0.7583482265472412
#
# step: 500
#  discriminator loss: 0.6890970468521118
#  adversarial loss: 0.7553541660308838
#
# step: 600
#  discriminator loss: 0.6961036920547485
#  adversarial loss: 0.7298117876052856
#
# step: 700
#  discriminator loss: 0.7000786066055298
#  adversarial loss: 0.8015920519828796
#
# step: 800
#  discriminator loss: 0.6920740604400635
#  adversarial loss: 0.8051015734672546
#
# step: 900
#  discriminator loss: 0.7011079788208008
#  adversarial loss: 0.7443011403083801
#
# step: 1000
#  discriminator loss: 0.6999775171279907
#  adversarial loss: 0.7544032335281372
#
# step: 1100
#  discriminator loss: 0.6971011757850647
#  adversarial loss: 0.7442325353622437
#
# step: 1200
#  discriminator loss: 0.6865346431732178
#  adversarial loss: 0.7287415266036987
#
# step: 1300
#  discriminator loss: 0.676634669303894
#  adversarial loss: 0.6900748610496521
#
# step: 1400
#  discriminator loss: 0.6824445724487305
#  adversarial loss: 0.7390588521957397
#
# step: 1500
#  discriminator loss: 0.6962010860443115
#  adversarial loss: 0.7899869680404663
#
# step: 1600
#  discriminator loss: 0.6982330679893494
#  adversarial loss: 0.7047103643417358
#
# step: 1700
#  discriminator loss: 0.6918640732765198
#  adversarial loss: 0.7430785894393921
#
# step: 1800
#  discriminator loss: 0.7075156569480896
#  adversarial loss: 0.7652029991149902
#
# step: 1900
#  discriminator loss: 0.7031875848770142
#  adversarial loss: 0.7598511576652527
#
# step: 2000
#  discriminator loss: 0.6919565200805664
#  adversarial loss: 0.7557309865951538
#
# step: 2100
#  discriminator loss: 0.6991742253303528
#  adversarial loss: 0.751908540725708
#
# step: 2200
#  discriminator loss: 0.6932793259620667
#  adversarial loss: 0.7600836753845215
#
# step: 2300
#  discriminator loss: 0.6959589719772339
#  adversarial loss: 0.7540474534034729
#
# step: 2400
#  discriminator loss: 0.6967973709106445
#  adversarial loss: 0.7112898826599121
#
# step: 2500
#  discriminator loss: 0.6840099096298218
#  adversarial loss: 0.7100943326950073
#
# step: 2600
#  discriminator loss: 0.6889112591743469
#  adversarial loss: 0.7997018694877625
#
# step: 2700
#  discriminator loss: 0.6943360567092896
#  adversarial loss: 0.760246753692627
#
# step: 2800
#  discriminator loss: 0.6999737024307251
#  adversarial loss: 0.7549675703048706
#
# step: 2900
#  discriminator loss: 0.7021238207817078
#  adversarial loss: 0.7369364500045776
#
# step: 3000
#  discriminator loss: 0.687336266040802
#  adversarial loss: 0.7300174832344055
#
# step: 3100
#  discriminator loss: 0.6944174766540527
#  adversarial loss: 0.7591437101364136
#
# step: 3200
#  discriminator loss: 0.6942895650863647
#  adversarial loss: 0.7686344385147095
#
# step: 3300
#  discriminator loss: 0.6996703147888184
#  adversarial loss: 0.7654814720153809
#
# step: 3400
#  discriminator loss: 0.6971338391304016
#  adversarial loss: 0.7291838526725769
#
# step: 3500
#  discriminator loss: 0.6950145959854126
#  adversarial loss: 0.8211351633071899
#
# step: 3600
#  discriminator loss: 0.7323035001754761
#  adversarial loss: 0.7331415414810181
#
# step: 3700
#  discriminator loss: 0.7298110723495483
#  adversarial loss: 0.8503071665763855
#
# step: 3800
#  discriminator loss: 0.693053126335144
#  adversarial loss: 0.7647837400436401
#
# step: 3900
#  discriminator loss: 0.6863375306129456
#  adversarial loss: 0.7572079300880432
#
# step: 4000
#  discriminator loss: 0.6935533285140991
#  adversarial loss: 0.7384708523750305
#
# step: 4100
#  discriminator loss: 0.6922359466552734
#  adversarial loss: 0.6916342973709106
#
# step: 4200
#  discriminator loss: 0.7141838669776917
#  adversarial loss: 0.7261626720428467
#
# step: 4300
#  discriminator loss: 0.6738301515579224
#  adversarial loss: 0.7761309146881104
#
# step: 4400
#  discriminator loss: 0.6976558566093445
#  adversarial loss: 0.4552900791168213
#
# step: 4500
#  discriminator loss: 0.6924220323562622
#  adversarial loss: 0.7224228382110596
#
# step: 4600
#  discriminator loss: 0.6813968420028687
#  adversarial loss: 0.8477034568786621
#
# step: 4700
#  discriminator loss: 0.6963999271392822
#  adversarial loss: 1.023476481437683
#
# step: 4800
#  discriminator loss: 0.6398810148239136
#  adversarial loss: 1.297457218170166
#
# step: 4900
#  discriminator loss: 0.6680117845535278
#  adversarial loss: 0.8579425811767578
#
# step: 5000
#  discriminator loss: 0.6761834025382996
#  adversarial loss: 0.915530800819397
#
# step: 5100
#  discriminator loss: 0.6928104162216187
#  adversarial loss: 0.7482681274414062
#
# step: 5200
#  discriminator loss: 0.6651818156242371
#  adversarial loss: 0.8780689239501953
#
# step: 5300
#  discriminator loss: 0.6528466939926147
#  adversarial loss: 0.7730394005775452
#
# step: 5400
#  discriminator loss: 0.7960406541824341
#  adversarial loss: 0.9374243021011353
#
# step: 5500
#  discriminator loss: 0.6804088950157166
#  adversarial loss: 0.9110637903213501
#
# step: 5600
#  discriminator loss: 0.6730326414108276
#  adversarial loss: 0.6849940419197083
#
# step: 5700
#  discriminator loss: 0.6967889070510864
#  adversarial loss: 0.7046290636062622
#
# step: 5800
#  discriminator loss: 0.6692054867744446
#  adversarial loss: 0.7280807495117188
#
# step: 5900
#  discriminator loss: 0.738510251045227
#  adversarial loss: 1.0335338115692139
#
# step: 6000
#  discriminator loss: 0.6539182066917419
#  adversarial loss: 0.8426327705383301
#
# step: 6100
#  discriminator loss: 0.6659926772117615
#  adversarial loss: 0.824632465839386
#
# step: 6200
#  discriminator loss: 0.6888478398323059
#  adversarial loss: 0.8460834622383118
#
# step: 6300
#  discriminator loss: 0.6718636155128479
#  adversarial loss: 0.9130586385726929
#
# step: 6400
#  discriminator loss: 0.6310141682624817
#  adversarial loss: 0.9967905879020691
#
# step: 6500
#  discriminator loss: 0.6779917478561401
#  adversarial loss: 0.8556399345397949
#
# step: 6600
#  discriminator loss: 0.6867579221725464
#  adversarial loss: 0.8432527780532837
#
# step: 6700
#  discriminator loss: 0.7627006769180298
#  adversarial loss: 0.8179243206977844
#
# step: 6800
#  discriminator loss: 0.6634031534194946
#  adversarial loss: 0.8631665110588074
#
# step: 6900
#  discriminator loss: 0.6479846239089966
#  adversarial loss: 0.7331984639167786
#
# step: 7000
#  discriminator loss: 0.6966490745544434
#  adversarial loss: 1.003901720046997
#
# step: 7100
#  discriminator loss: 0.6619690656661987
#  adversarial loss: 0.7056704759597778
#
# step: 7200
#  discriminator loss: 0.6923397779464722
#  adversarial loss: 0.7703747749328613
#
# step: 7300
#  discriminator loss: 0.709362268447876
#  adversarial loss: 0.7714234590530396
#
# step: 7400
#  discriminator loss: 0.6858953237533569
#  adversarial loss: 0.7362711429595947
#
# step: 7500
#  discriminator loss: 0.6891424059867859
#  adversarial loss: 0.7502387762069702
#
# step: 7600
#  discriminator loss: 0.6686209440231323
#  adversarial loss: 0.7756885290145874
#
# step: 7700
#  discriminator loss: 0.6988873481750488
#  adversarial loss: 0.762656569480896
#
# step: 7800
#  discriminator loss: 0.661638081073761
#  adversarial loss: 0.838026225566864
#
# step: 7900
#  discriminator loss: 0.6898869276046753
#  adversarial loss: 0.7844707369804382
#
# step: 8000
#  discriminator loss: 0.6896518468856812
#  adversarial loss: 0.7741107940673828
#
# step: 8100
#  discriminator loss: 0.6930992007255554
#  adversarial loss: 0.8851014375686646
#
# step: 8200
#  discriminator loss: 0.6914381980895996
#  adversarial loss: 0.8389781713485718
#
# step: 8300
#  discriminator loss: 0.762182891368866
#  adversarial loss: 0.9598724246025085
#
# step: 8400
#  discriminator loss: 0.6672723889350891
#  adversarial loss: 0.6897571682929993
#
# step: 8500
#  discriminator loss: 0.6842538118362427
#  adversarial loss: 0.7821152806282043
#
# step: 8600
#  discriminator loss: 0.7269054651260376
#  adversarial loss: 0.5966450572013855
#
# step: 8700
#  discriminator loss: 0.7013257145881653
#  adversarial loss: 0.8759247660636902
#
# step: 8800
#  discriminator loss: 0.6920516490936279
#  adversarial loss: 0.7615287899971008
#
# step: 8900
#  discriminator loss: 0.6732140779495239
#  adversarial loss: 0.7443567514419556
#
# step: 9000
#  discriminator loss: 0.7287022471427917
#  adversarial loss: 1.2219570875167847
#
# step: 9100
#  discriminator loss: 0.7081718444824219
#  adversarial loss: 0.6693540811538696
#
# step: 9200
#  discriminator loss: 0.7146497964859009
#  adversarial loss: 0.788215160369873
#
# step: 9300
#  discriminator loss: 0.6704345941543579
#  adversarial loss: 0.7283044457435608
#
# step: 9400
#  discriminator loss: 0.6818354725837708
#  adversarial loss: 0.7471999526023865
#
# step: 9500
#  discriminator loss: 0.7015020251274109
#  adversarial loss: 0.8300849795341492
#
# step: 9600
#  discriminator loss: 0.6583461165428162
#  adversarial loss: 0.7750314474105835
#
# step: 9700
#  discriminator loss: 0.6920917630195618
#  adversarial loss: 0.800635814666748
#
# step: 9800
#  discriminator loss: 0.6585849523544312
#  adversarial loss: 0.8101403117179871
#
# step: 9900
#  discriminator loss: 0.7811347842216492
#  adversarial loss: 0.6132158041000366

# %% [markdown]
# #### 이미지 생성을 통한 시각화

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# - 잠재 공간에서 랜덤한 포인트를 샘플링

# %%
random_latent_vectors = np.random.normal(size=(10, latent_dim)) # 10개만

# %% [markdown]
# - 가짜 이미지로 디코딩

# %%
generated_images = generator.predict(random_latent_vectors)

# %%
print(generated_images.shape)
# Out:
# (10, 32, 32, 3)

# %%
plt.figure(figsize=(20, 8))
for i in range(generated_images.shape[0]):
  plt.subplot(2, 5, i+1)
  img = image.array_to_img(generated_images[i] * 255., scale=False)
  plt.imshow(img)
  plt.xticks([])
  plt.yticks([])

plt.show()
