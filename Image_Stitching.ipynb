# %% [markdown]
# # Image Stitching
#
# - 영상 이어 붙이기
#
# - Image Stitching Algorithm (참고)
#
#   <img src="https://docs.opencv.org/3.4/StitchingPipeline.jpg">
#
#   [이미지 출처] https://docs.opencv.org/3.4/d1/d46/group__stitching.html
#
# <br>
#
# - `cv2.create()`
#
#   - `Parameters`
#
#     - `mode` : 이어붙이기 방식
#
#       - `PANORAMA`
#
#       - `SCANS`
#   - `반환값` : stitcher 객체
#
# - `cv2.stitch()`
#
#   - `Parameters`
#
#     - `images` : 입력 영상의 벡터
#
#     - `pano` : 출력 파노라마 영상
#
#   - `반환값` : 함수 동작 결과 코드

# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np

# %%
imgs = []

# %%
img1 = cv2.imread('/content/image1.jpg')
img2 = cv2.imread('/content/image2.jpg')

# %%
cv2_imshow(img1)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x667 at 0x7FBD6569FA90>

# %%
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x683 at 0x7FBD6569FAC8>

# %%
imgs.append(img1)
imgs.append(img2)

# %%
len(imgs)
# Out:
# 2

# %%
stitcher = cv2.Stitcher_create()

# %%
status, dst = stitcher.stitch(imgs)

# %%
cv2_imshow(dst)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-80-4233a4702d94> in <module>()
# ----> 1 cv2_imshow(dst)
#
# /usr/local/lib/python3.6/dist-packages/google/colab/patches/__init__.py in cv2_imshow(a)
#      20       image.
#      21   """
# ---> 22   a = a.clip(0, 255).astype('uint8')
#      23   # cv2 stores colors as BGR; convert to RGB
#      24   if a.ndim == 3:
#
# AttributeError: 'NoneType' object has no attribute 'clip'
